# %% [markdown]
# ### The German Traffic Sign Benchmark
#
# Student Name 1: ...
#
# Student Name 2: ...

# %% [markdown]
# Download full data set from http://benchmark.ini.rub.de/?section=gtsdb&subsection=dataset

# %%
# !wget -c http://benchmark.ini.rub.de/Dataset_GTSDB/FullIJCNN2013.zip
# !unzip FullIJCNN2013.zip
# Out:
# --2019-03-25 16:07:23--  http://benchmark.ini.rub.de/Dataset_GTSDB/FullIJCNN2013.zip
# Resolving benchmark.ini.rub.de (benchmark.ini.rub.de)... 134.147.122.15
# Connecting to benchmark.ini.rub.de (benchmark.ini.rub.de)|134.147.122.15|:80... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# Archive:  FullIJCNN2013.zip
# replace FullIJCNN2013/00000.ppm? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
import numpy as np
import cv2

IMG_HEIGHT = 600
SIGN_SIZE = (32, 32) #(224, 224)

# Function for reading the images
def readImages(rootpath, images_range, signs_range):
    '''Reads traffic sign data for German Traffic Sign Recognition Benchmark.
    Arguments: path to the traffic sign data, for example 'FullIJCNN2013'
    Returns:   list of images, list of corresponding labels'''
    images = {} # original image
    scales = {} # original scale
    for num in images_range:
        filename = rootpath + '/' + "{:05d}".format(num) + '.ppm'
        img = cv2.imread(filename, cv2.IMREAD_COLOR)
        scale = IMG_HEIGHT / float(img.shape[0])
        img_resized = cv2.resize(img, (int(img.shape[1]*scale),int(img.shape[0]*scale)))
        images.setdefault(filename,[]).append(img_resized)
        scales.setdefault(filename,[]).append(scale)

    files = [] # filenames
    signs = [] # traffic sign image
    bboxes = [] # corresponding box detection
    labels = [] # traffic sign type
    data = np.genfromtxt(rootpath + '/' + 'gt.txt', delimiter=';', dtype=str, usecols=range(0, 6))
    for elem in signs_range:
        filename = rootpath + '/' + data[elem][0]
        img = images.get(filename)[0]
        scale = scales.get(filename)[0]
        bbox = np.array([int(data[elem][1]), int(data[elem][2]), int(data[elem][3]), int(data[elem][4])]) * scale
        sign = img[int(bbox[1]):int(bbox[3]), int(bbox[0]):int(bbox[2])]
        sign_resized = cv2.resize(sign, SIGN_SIZE)
        files.append(filename)
        signs.append(sign_resized)
        bboxes.append(bbox)
        labels.append(data[elem][5])
    return images, files, signs, bboxes, labels

# %%
# The German Traffic Sign Recognition Benchmark
train_images, train_files, train_signs, train_bboxes, train_labels = readImages('FullIJCNN2013', range(0,600), range(0,852))
test_images, test_files, test_signs, test_bboxes, test_labels = readImages('FullIJCNN2013', range(600,900), range(852,1213))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

# Show examples from each class
class_names = np.unique(train_labels)
num_classes = len(class_names)
fig = plt.figure(figsize=(8,8))
for i in range(num_classes):
    ax = fig.add_subplot(6, 9, 1 + i, xticks=[], yticks=[])
    ax.set_title(class_names[i])
    indices = np.where(np.isin(train_labels, class_names[i]))[0]
    plt.imshow(cv2.cvtColor(train_signs[int(np.random.choice(indices, 1))], cv2.COLOR_BGR2RGB))
plt.show()

# %%
from sklearn.utils import shuffle
train_files, train_signs, train_bboxes, train_labels = shuffle(train_files, train_signs, train_bboxes, train_labels)
# plt.imshow(cv2.cvtColor(train_images.get(train_files[0])[0], cv2.COLOR_BGR2RGB))
# plt.show()
# plt.imshow(cv2.cvtColor(train_signs[0], cv2.COLOR_BGR2RGB))
# plt.show()
# print(train_bboxes[0])
# print(train_labels[0])

# Data pre-processing
tr_signs = np.array(train_signs)[0:600]
tr_labels = np.array(train_labels)[0:600]
va_signs = np.array(train_signs)[600:852]
va_labels = np.array(train_labels)[600:852]
te_signs = np.array(test_signs)
te_labels = np.array(test_labels)

tr_signs = tr_signs.astype('float32')
va_signs = va_signs.astype('float32')
te_signs = te_signs.astype('float32')
tr_signs /= 255.0
va_signs /= 255.0
te_signs /= 255.0

from keras.utils import np_utils
tr_labels = np_utils.to_categorical(tr_labels, num_classes)
va_labels = np_utils.to_categorical(va_labels, num_classes)
te_labels = np_utils.to_categorical(te_labels, num_classes)
# Out:
# Using TensorFlow backend.

# %%
# Tensorboard
from time import time
from keras.callbacks import TensorBoard, EarlyStopping
tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))

# %% [markdown]
# ### Assignment 1: Multi-Layer Perceptron

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, LeakyReLU
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras import initializers

act = LeakyReLU(alpha=0.3)
#init_method = initializers.he_normal(seed=256)

mlp = Sequential()
mlp.add(Dense(1, input_shape=(SIGN_SIZE[0], SIGN_SIZE[1], 3)))
mlp.add(Flatten())
mlp.add(Activation(act))
mlp.add(Dropout(0.15))

mlp.add(BatchNormalization())
mlp.add(Dense(2048))
mlp.add(Activation(act))
mlp.add(Dropout(0.3))

mlp.add(Dense(1024))
mlp.add(Activation(act))
mlp.add(Dropout(0.3))

mlp.add(Dense(256))
mlp.add(Activation(act))
mlp.add(Dropout(0.3))

mlp.add(Dense(256))
mlp.add(Activation(act))
mlp.add(Dropout(0.3))

mlp.add(Dense(100))
mlp.add(Activation(act))
mlp.add(Dropout(0.3))

mlp.add(Dense(num_classes))
mlp.add(Activation('softmax'))

# optimization
opt = optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
#opt = optimizers.Adam(lr=0.001)
#opt = optimizers.Adagrad(lr=0.01, epsilon=None, decay=0.0)
#opt = optimizers.Adadelta(lr=1.0, rho=0.95, epsilon=None, decay=0.0)
#opt = optimizers.Adamax(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)

# data augmentation
datagen = ImageDataGenerator(featurewise_center=False,
                             featurewise_std_normalization=False,
                             width_shift_range=0.1,
                             height_shift_range=0.1,
                             zoom_range=0.2,
                             shear_range=0.1,
                             rotation_range=10.)

datagen.fit(tr_signs)

mlp.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
mlp.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/keras/activations.py:211: UserWarning: Do not pass a layer instance (such as LeakyReLU) as the activation argument of another layer. Instead, advanced activation layers should be used just like any other layer in a model.
#   identifier=identifier.__class__.__name__))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32, 32, 1)         4
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_2 (Dense)              (None, 2048)              2099200
# _________________________________________________________________
# activation_2 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# activation_3 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               262400
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               25700
# _________________________________________________________________
# activation_6 (Activation)    (None, 100)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 43)                4343
# _________________________________________________________________
# activation_7 (Activation)    (None, 43)                0
# =================================================================
# Total params: 4,559,711
# Trainable params: 4,557,663
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
# early stopping
es = EarlyStopping(monitor='val_loss', verbose=1, patience=50, min_delta = 2)

data = mlp.fit(tr_signs, tr_labels, batch_size=16, epochs=300, verbose=2, validation_data=(va_signs, va_labels), callbacks=[tensorboard])

# enable this for data augmentation
#data = mlp.fit_generator(datagen.flow(tr_signs, tr_labels, batch_size=16), steps_per_epoch=tr_signs.shape[0], epochs=70, validation_data=(va_signs, va_labels),callbacks=[es,tensorboard])


start = time()
loss, acc = mlp.evaluate(te_signs, te_labels, verbose=0)
end = time()
print('MLP took ' + str(end - start) + ' seconds')
print('Test loss: ' + str(loss) + ' - Accuracy: ' + str(acc))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 600 samples, validate on 252 samples
# Epoch 1/300
#  - 1s - loss: 3.8765 - acc: 0.0583 - val_loss: 3.4769 - val_acc: 0.1786
# Epoch 2/300
#  - 0s - loss: 3.5496 - acc: 0.1117 - val_loss: 3.3363 - val_acc: 0.2302
# Epoch 3/300
#  - 0s - loss: 3.4053 - acc: 0.1267 - val_loss: 3.2409 - val_acc: 0.2540
# Epoch 4/300
#  - 0s - loss: 3.3663 - acc: 0.1250 - val_loss: 3.1605 - val_acc: 0.2421
# Epoch 5/300
#  - 0s - loss: 3.3061 - acc: 0.1383 - val_loss: 3.0563 - val_acc: 0.2778
# Epoch 6/300
#  - 0s - loss: 3.1108 - acc: 0.2000 - val_loss: 2.9525 - val_acc: 0.2778
# Epoch 7/300
#  - 0s - loss: 2.9739 - acc: 0.1900 - val_loss: 2.8431 - val_acc: 0.2897
# Epoch 8/300
#  - 0s - loss: 2.9288 - acc: 0.2383 - val_loss: 2.7309 - val_acc: 0.3611
# Epoch 9/300
#  - 0s - loss: 2.8270 - acc: 0.2550 - val_loss: 2.6213 - val_acc: 0.3611
# Epoch 10/300
#  - 0s - loss: 2.6824 - acc: 0.2883 - val_loss: 2.4825 - val_acc: 0.3889
# Epoch 11/300
#  - 0s - loss: 2.5921 - acc: 0.3050 - val_loss: 2.4185 - val_acc: 0.3611
# Epoch 12/300
#  - 0s - loss: 2.5565 - acc: 0.3183 - val_loss: 2.2680 - val_acc: 0.4127
# Epoch 13/300
#  - 0s - loss: 2.4482 - acc: 0.3567 - val_loss: 2.1473 - val_acc: 0.4563
# Epoch 14/300
#  - 0s - loss: 2.3152 - acc: 0.3667 - val_loss: 2.1261 - val_acc: 0.4365
# Epoch 15/300
#  - 0s - loss: 2.2010 - acc: 0.3783 - val_loss: 1.9857 - val_acc: 0.4484
# Epoch 16/300
#  - 0s - loss: 2.1284 - acc: 0.4333 - val_loss: 1.9183 - val_acc: 0.4722
# Epoch 17/300
#  - 0s - loss: 2.0130 - acc: 0.4600 - val_loss: 1.8153 - val_acc: 0.4841
# Epoch 18/300
#  - 0s - loss: 1.9738 - acc: 0.4433 - val_loss: 1.8416 - val_acc: 0.4762
# Epoch 19/300
#  - 0s - loss: 1.9745 - acc: 0.4417 - val_loss: 1.7103 - val_acc: 0.5317
# Epoch 20/300
#  - 0s - loss: 1.8243 - acc: 0.4917 - val_loss: 1.6769 - val_acc: 0.5159
# Epoch 21/300
#  - 0s - loss: 1.7658 - acc: 0.4850 - val_loss: 1.6453 - val_acc: 0.5437
# Epoch 22/300
#  - 0s - loss: 1.7830 - acc: 0.4883 - val_loss: 1.5746 - val_acc: 0.5238
# Epoch 23/300
#  - 0s - loss: 1.6452 - acc: 0.5233 - val_loss: 1.4992 - val_acc: 0.5833
# Epoch 24/300
#  - 0s - loss: 1.6436 - acc: 0.5300 - val_loss: 1.5452 - val_acc: 0.5595
# Epoch 25/300
#  - 0s - loss: 1.6138 - acc: 0.5433 - val_loss: 1.4656 - val_acc: 0.5992
# Epoch 26/300
#  - 0s - loss: 1.5411 - acc: 0.5517 - val_loss: 1.4449 - val_acc: 0.6190
# Epoch 27/300
#  - 0s - loss: 1.5816 - acc: 0.5300 - val_loss: 1.4305 - val_acc: 0.6190
# Epoch 28/300
#  - 0s - loss: 1.5151 - acc: 0.5450 - val_loss: 1.4062 - val_acc: 0.6111
# Epoch 29/300
#  - 0s - loss: 1.4731 - acc: 0.5583 - val_loss: 1.3837 - val_acc: 0.6230
# Epoch 30/300
#  - 0s - loss: 1.4167 - acc: 0.5800 - val_loss: 1.3311 - val_acc: 0.6230
# Epoch 31/300
#  - 0s - loss: 1.4059 - acc: 0.6050 - val_loss: 1.3248 - val_acc: 0.6310
# Epoch 32/300
#  - 0s - loss: 1.4489 - acc: 0.5817 - val_loss: 1.3115 - val_acc: 0.6349
# Epoch 33/300
#  - 0s - loss: 1.3398 - acc: 0.5933 - val_loss: 1.3242 - val_acc: 0.6389
# Epoch 34/300
#  - 0s - loss: 1.3451 - acc: 0.6017 - val_loss: 1.2976 - val_acc: 0.6508
# Epoch 35/300
#  - 0s - loss: 1.3039 - acc: 0.6133 - val_loss: 1.2612 - val_acc: 0.6587
# Epoch 36/300
#  - 0s - loss: 1.2493 - acc: 0.6450 - val_loss: 1.2487 - val_acc: 0.6786
# Epoch 37/300
#  - 0s - loss: 1.3166 - acc: 0.6167 - val_loss: 1.2085 - val_acc: 0.6627
# Epoch 38/300
#  - 0s - loss: 1.2299 - acc: 0.6367 - val_loss: 1.1644 - val_acc: 0.6706
# Epoch 39/300
#  - 0s - loss: 1.2022 - acc: 0.6383 - val_loss: 1.1725 - val_acc: 0.6905
# Epoch 40/300
#  - 0s - loss: 1.1946 - acc: 0.6367 - val_loss: 1.1411 - val_acc: 0.6786
# Epoch 41/300
#  - 0s - loss: 1.1458 - acc: 0.6667 - val_loss: 1.1369 - val_acc: 0.6865
# Epoch 42/300
#  - 0s - loss: 1.1597 - acc: 0.6517 - val_loss: 1.1515 - val_acc: 0.6984
# Epoch 43/300
#  - 0s - loss: 1.1697 - acc: 0.6633 - val_loss: 1.0960 - val_acc: 0.6944
# Epoch 44/300
#  - 0s - loss: 1.0921 - acc: 0.6783 - val_loss: 1.1130 - val_acc: 0.6667
# Epoch 45/300
#  - 0s - loss: 1.1340 - acc: 0.6700 - val_loss: 1.0798 - val_acc: 0.7103
# Epoch 46/300
#  - 0s - loss: 1.0611 - acc: 0.6750 - val_loss: 1.0204 - val_acc: 0.7183
# Epoch 47/300
#  - 0s - loss: 1.0828 - acc: 0.6883 - val_loss: 1.0400 - val_acc: 0.7143
# Epoch 48/300
#  - 0s - loss: 1.0202 - acc: 0.6900 - val_loss: 1.0232 - val_acc: 0.7222
# Epoch 49/300
#  - 0s - loss: 0.9632 - acc: 0.7067 - val_loss: 1.0148 - val_acc: 0.7262
# Epoch 202/300
#  - 0s - loss: 0.3578 - acc: 0.8817 - val_loss: 0.8090 - val_acc: 0.7937
# Epoch 203/300
#  - 0s - loss: 0.3392 - acc: 0.8867 - val_loss: 0.8072 - val_acc: 0.7817
# Epoch 204/300
#  - 0s - loss: 0.3873 - acc: 0.8733 - val_loss: 0.8147 - val_acc: 0.7937
# Epoch 205/300
#  - 0s - loss: 0.2944 - acc: 0.9167 - val_loss: 0.7840 - val_acc: 0.7937
# Epoch 206/300
#  - 0s - loss: 0.4218 - acc: 0.8667 - val_loss: 0.8148 - val_acc: 0.7937
# Epoch 207/300
#  - 0s - loss: 0.3437 - acc: 0.9000 - val_loss: 0.7535 - val_acc: 0.8016
# Epoch 208/300
#  - 0s - loss: 0.2985 - acc: 0.9083 - val_loss: 0.7770 - val_acc: 0.7897
# Epoch 209/300
#  - 0s - loss: 0.3041 - acc: 0.9133 - val_loss: 0.7846 - val_acc: 0.8056
# Epoch 210/300
#  - 0s - loss: 0.4112 - acc: 0.8817 - val_loss: 0.7594 - val_acc: 0.7937
# Epoch 211/300
#  - 0s - loss: 0.3770 - acc: 0.8867 - val_loss: 0.7355 - val_acc: 0.8016
# Epoch 212/300
#  - 0s - loss: 0.3330 - acc: 0.8917 - val_loss: 0.7687 - val_acc: 0.7937
# Epoch 213/300
#  - 0s - loss: 0.3709 - acc: 0.8750 - val_loss: 0.7479 - val_acc: 0.8095
# Epoch 214/300
#  - 0s - loss: 0.3993 - acc: 0.8867 - val_loss: 0.7398 - val_acc: 0.7937
# Epoch 215/300
#  - 0s - loss: 0.3091 - acc: 0.9067 - val_loss: 0.7410 - val_acc: 0.8056
# Epoch 216/300
#  - 0s - loss: 0.3424 - acc: 0.8933 - val_loss: 0.7589 - val_acc: 0.7976
# Epoch 217/300
#  - 0s - loss: 0.2988 - acc: 0.9117 - val_loss: 0.7792 - val_acc: 0.7976
# Epoch 218/300
#  - 0s - loss: 0.2604 - acc: 0.9250 - val_loss: 0.8434 - val_acc: 0.7897
# Epoch 219/300
#  - 0s - loss: 0.3059 - acc: 0.9100 - val_loss: 0.7885 - val_acc: 0.7937
# Epoch 220/300
#  - 0s - loss: 0.3798 - acc: 0.8833 - val_loss: 0.7632 - val_acc: 0.8095
# Epoch 221/300
#  - 0s - loss: 0.2755 - acc: 0.9150 - val_loss: 0.8286 - val_acc: 0.7738
# Epoch 222/300
#  - 0s - loss: 0.2741 - acc: 0.9000 - val_loss: 0.7732 - val_acc: 0.7976
# Epoch 223/300
#  - 0s - loss: 0.2853 - acc: 0.9000 - val_loss: 0.7547 - val_acc: 0.8016
# Epoch 224/300
#  - 0s - loss: 0.3310 - acc: 0.8800 - val_loss: 0.7663 - val_acc: 0.7976
# Epoch 225/300
#  - 0s - loss: 0.2962 - acc: 0.8983 - val_loss: 0.7535 - val_acc: 0.7976
# Epoch 226/300
#  - 0s - loss: 0.3011 - acc: 0.9083 - val_loss: 0.7722 - val_acc: 0.8056
# Epoch 227/300
#  - 0s - loss: 0.3537 - acc: 0.8900 - val_loss: 0.7522 - val_acc: 0.7976
# Epoch 228/300
#  - 0s - loss: 0.3264 - acc: 0.9100 - val_loss: 0.7556 - val_acc: 0.7897
# Epoch 229/300
#  - 0s - loss: 0.3507 - acc: 0.9050 - val_loss: 0.8805 - val_acc: 0.7778
# Epoch 230/300
#  - 0s - loss: 0.3261 - acc: 0.8917 - val_loss: 0.7895 - val_acc: 0.7976
# Epoch 231/300
#  - 0s - loss: 0.2651 - acc: 0.9250 - val_loss: 0.8265 - val_acc: 0.7857
# Epoch 232/300
#  - 0s - loss: 0.2806 - acc: 0.9017 - val_loss: 0.7420 - val_acc: 0.8095
# Epoch 233/300
#  - 0s - loss: 0.3684 - acc: 0.8950 - val_loss: 0.7500 - val_acc: 0.7897
# Epoch 234/300
#  - 0s - loss: 0.3093 - acc: 0.9050 - val_loss: 0.7732 - val_acc: 0.7937
# Epoch 235/300
#  - 0s - loss: 0.3686 - acc: 0.8850 - val_loss: 0.8368 - val_acc: 0.7937
# Epoch 236/300
#  - 0s - loss: 0.3225 - acc: 0.8900 - val_loss: 0.8841 - val_acc: 0.7857
# Epoch 237/300
#  - 0s - loss: 0.3095 - acc: 0.9017 - val_loss: 0.7651 - val_acc: 0.8056
# Epoch 238/300
#  - 0s - loss: 0.3295 - acc: 0.9000 - val_loss: 0.7506 - val_acc: 0.8056
# Epoch 239/300
#  - 0s - loss: 0.3228 - acc: 0.9133 - val_loss: 0.7653 - val_acc: 0.8214
# Epoch 240/300
#  - 0s - loss: 0.2516 - acc: 0.9400 - val_loss: 0.7351 - val_acc: 0.7937
# Epoch 241/300
#  - 0s - loss: 0.2729 - acc: 0.9250 - val_loss: 0.7146 - val_acc: 0.8135
# Epoch 242/300
#  - 0s - loss: 0.2440 - acc: 0.9267 - val_loss: 0.7064 - val_acc: 0.8135
# Epoch 243/300
#  - 0s - loss: 0.2773 - acc: 0.9033 - val_loss: 0.7262 - val_acc: 0.8135
# Epoch 244/300
#  - 0s - loss: 0.3456 - acc: 0.8967 - val_loss: 0.7074 - val_acc: 0.8016
# Epoch 245/300
#  - 0s - loss: 0.2945 - acc: 0.9017 - val_loss: 0.7540 - val_acc: 0.8095
# Epoch 246/300
#  - 0s - loss: 0.3216 - acc: 0.8950 - val_loss: 0.7646 - val_acc: 0.7698
# Epoch 247/300
#  - 0s - loss: 0.3499 - acc: 0.8883 - val_loss: 0.7904 - val_acc: 0.7738
# Epoch 248/300
#  - 0s - loss: 0.3058 - acc: 0.9050 - val_loss: 0.7319 - val_acc: 0.8016
# Epoch 249/300
#  - 0s - loss: 0.2891 - acc: 0.9233 - val_loss: 0.7333 - val_acc: 0.7937
# Epoch 250/300
#  - 0s - loss: 0.2749 - acc: 0.9083 - val_loss: 0.8835 - val_acc: 0.7778
# Epoch 251/300
#  - 0s - loss: 0.2964 - acc: 0.9100 - val_loss: 0.8027 - val_acc: 0.7937
# Epoch 252/300
#  - 0s - loss: 0.2775 - acc: 0.9083 - val_loss: 0.7846 - val_acc: 0.7937
# Epoch 253/300
#  - 0s - loss: 0.3194 - acc: 0.9117 - val_loss: 0.8220 - val_acc: 0.8095
# Epoch 254/300
#  - 0s - loss: 0.2952 - acc: 0.9100 - val_loss: 0.7912 - val_acc: 0.7976
# Epoch 255/300
#  - 0s - loss: 0.2745 - acc: 0.9000 - val_loss: 0.7810 - val_acc: 0.8095
# Epoch 256/300
#  - 0s - loss: 0.2892 - acc: 0.9117 - val_loss: 0.7994 - val_acc: 0.7897
# Epoch 257/300
#  - 0s - loss: 0.3044 - acc: 0.9117 - val_loss: 0.7573 - val_acc: 0.8135
# Epoch 258/300
#  - 0s - loss: 0.2797 - acc: 0.9133 - val_loss: 0.7492 - val_acc: 0.8095
# Epoch 259/300
#  - 0s - loss: 0.3067 - acc: 0.9200 - val_loss: 0.7643 - val_acc: 0.7937
# Epoch 260/300
#  - 0s - loss: 0.3227 - acc: 0.8983 - val_loss: 0.7622 - val_acc: 0.7937
# Epoch 261/300
#  - 0s - loss: 0.3108 - acc: 0.9067 - val_loss: 0.7905 - val_acc: 0.7857
# Epoch 262/300
#  - 0s - loss: 0.3187 - acc: 0.8983 - val_loss: 0.8697 - val_acc: 0.7937
# Epoch 263/300
#  - 0s - loss: 0.3309 - acc: 0.8917 - val_loss: 0.8300 - val_acc: 0.7897
# Epoch 264/300
#  - 0s - loss: 0.3149 - acc: 0.9150 - val_loss: 0.8097 - val_acc: 0.7857
# Epoch 265/300
#  - 0s - loss: 0.3028 - acc: 0.9200 - val_loss: 0.8327 - val_acc: 0.7976
# Epoch 266/300
#  - 0s - loss: 0.2201 - acc: 0.9350 - val_loss: 0.8014 - val_acc: 0.7738
# Epoch 267/300
#  - 0s - loss: 0.3102 - acc: 0.8850 - val_loss: 0.8532 - val_acc: 0.7738
# Epoch 268/300
#  - 0s - loss: 0.2311 - acc: 0.9267 - val_loss: 0.8612 - val_acc: 0.7897
# Epoch 269/300
#  - 0s - loss: 0.3057 - acc: 0.9067 - val_loss: 0.8189 - val_acc: 0.8016
# Epoch 270/300
#  - 0s - loss: 0.3094 - acc: 0.9133 - val_loss: 0.8713 - val_acc: 0.7738
# Epoch 271/300
#  - 0s - loss: 0.2925 - acc: 0.9150 - val_loss: 0.7634 - val_acc: 0.8135
# Epoch 272/300
#  - 0s - loss: 0.3011 - acc: 0.9150 - val_loss: 0.7494 - val_acc: 0.8095
# Epoch 273/300
#  - 0s - loss: 0.3313 - acc: 0.8983 - val_loss: 0.7920 - val_acc: 0.7857
# Epoch 274/300
#  - 0s - loss: 0.2716 - acc: 0.9167 - val_loss: 0.7972 - val_acc: 0.7897
# Epoch 275/300
#  - 0s - loss: 0.2864 - acc: 0.9200 - val_loss: 0.7945 - val_acc: 0.8056
# Epoch 276/300
#  - 0s - loss: 0.2822 - acc: 0.9200 - val_loss: 0.8245 - val_acc: 0.7976
# Epoch 277/300
#  - 0s - loss: 0.2654 - acc: 0.9150 - val_loss: 0.7546 - val_acc: 0.8056
# Epoch 278/300
#  - 0s - loss: 0.2673 - acc: 0.9200 - val_loss: 0.8410 - val_acc: 0.7937
# Epoch 279/300
#  - 0s - loss: 0.2703 - acc: 0.9100 - val_loss: 0.8409 - val_acc: 0.7778
# Epoch 280/300
#  - 0s - loss: 0.2403 - acc: 0.9083 - val_loss: 0.7708 - val_acc: 0.8056
# Epoch 281/300
#  - 0s - loss: 0.2391 - acc: 0.9133 - val_loss: 0.9011 - val_acc: 0.7857
# Epoch 282/300
#  - 0s - loss: 0.2687 - acc: 0.9267 - val_loss: 0.8425 - val_acc: 0.7897
# Epoch 283/300
#  - 0s - loss: 0.2856 - acc: 0.9200 - val_loss: 0.8277 - val_acc: 0.7937
# Epoch 284/300
#  - 0s - loss: 0.3072 - acc: 0.9067 - val_loss: 0.7828 - val_acc: 0.8016
# Epoch 285/300
#  - 0s - loss: 0.2913 - acc: 0.9100 - val_loss: 0.7604 - val_acc: 0.8056
# Epoch 286/300
#  - 0s - loss: 0.2574 - acc: 0.9217 - val_loss: 0.8061 - val_acc: 0.7937
# Epoch 287/300
#  - 0s - loss: 0.2780 - acc: 0.9133 - val_loss: 0.7930 - val_acc: 0.8135
# Epoch 288/300
#  - 0s - loss: 0.2279 - acc: 0.9267 - val_loss: 0.9197 - val_acc: 0.7659
# Epoch 289/300
#  - 0s - loss: 0.3015 - acc: 0.9200 - val_loss: 0.8005 - val_acc: 0.8016
# Epoch 290/300
#  - 0s - loss: 0.2376 - acc: 0.9200 - val_loss: 0.8520 - val_acc: 0.8016
# Epoch 291/300
#  - 0s - loss: 0.2274 - acc: 0.9367 - val_loss: 0.8077 - val_acc: 0.8135
# Epoch 292/300
#  - 0s - loss: 0.2418 - acc: 0.9167 - val_loss: 0.8389 - val_acc: 0.7857
# Epoch 293/300
#  - 0s - loss: 0.3359 - acc: 0.9150 - val_loss: 0.8999 - val_acc: 0.7857
# Epoch 294/300
#  - 0s - loss: 0.2761 - acc: 0.9167 - val_loss: 0.8452 - val_acc: 0.7897
# Epoch 295/300
#  - 0s - loss: 0.2451 - acc: 0.9283 - val_loss: 0.8871 - val_acc: 0.7976
# Epoch 296/300
#  - 0s - loss: 0.2771 - acc: 0.9083 - val_loss: 0.8136 - val_acc: 0.7937
# Epoch 297/300
#  - 0s - loss: 0.2518 - acc: 0.9067 - val_loss: 0.8103 - val_acc: 0.7937
# Epoch 298/300
#  - 0s - loss: 0.2765 - acc: 0.9167 - val_loss: 0.8340 - val_acc: 0.7778
# Epoch 299/300
#  - 0s - loss: 0.2668 - acc: 0.9167 - val_loss: 0.8522 - val_acc: 0.7897
# Epoch 300/300
#  - 0s - loss: 0.2297 - acc: 0.9300 - val_loss: 0.7899 - val_acc: 0.7937
# MLP took 0.053617238998413086 seconds
# Test loss: 0.4928138810841991 - Accuracy: 0.8781163436554146

# %%
acc
# Out:
# 0.8781163436554146

# %%
plt.plot(data.history['acc'])
plt.plot(data.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(data.history['loss'])
plt.plot(data.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
